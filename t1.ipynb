# %%
# !ls
# Out:
#  archive.zip
#  fipe_2022.csv
#  fipe_cars.csv
#  kaíke.ipynb
#  netflix
# 'netflix (1)'
#  pop-rs.rnp.br_~berthold_apl_datascience_07-precocarros_PrecoDosCarros.ipynb
#  PrecoDosCarros.ipynb
#  tabela-fipe-historico-precos.csv
#  Trabalho.ipynb
#  Untitled1.ipynb
#  untitled1.txt
#  Untitled2.ipynb
#  untitled2.txt
#  Untitled3.ipynb
#  Untitled4.ipynb
#  Untitled5.ipynb
#  Untitled.ipynb
#  untitled.md
#  untitled.txt
#  Video_Games.csv

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from scipy import stats

# %%
df = pd.read_csv("Video_Games.csv")

# %%
df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
plt.figure(figsize=(12, 6))
plt.scatter(df['Year_of_Release'], df['Critic_Count'], alpha=0.5)
plt.xlabel('Ano de Lançamento')
plt.ylabel('Contagem de Críticas')
plt.title('Relação entre Ano de Lançamento e Contagem de Críticas')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
genre_platform_counts = df.groupby(['Genre', 'Platform']).size().unstack()
genre_platform_counts.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.xlabel('Gênero')
plt.ylabel('Número de Jogos')
plt.title('Distribuição de Gênero por Plataforma')
plt.legend(title='Plataforma')
plt.show()

# %%
platform_year_counts = df.groupby(['Platform', 'Year_of_Release']).size().unstack()

platform_year_counts.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.xlabel('Plataforma')
plt.ylabel('Número de Jogos')
plt.title('Número de Jogos por Plataforma e Ano de Lançamento')
plt.legend(title='Ano de Lançamento')
plt.show()
